# %%
from random import choice
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
lista_animales=['oso','perro','gato','caballo','hipopotamo']
lista_paises=['mexico','japon','rusia','españa','afganistan']
lista_disney=['mulan','buscando a Nemo']
categorias=['animales','paises','peliculas de disney']

categoria=input("Elige una categoría entre animales, paises y peliculas de Disney").lower()
while categoria not in categorias:
        categoria=input("Categorìa invalida, por favor elige una categoría entre animales, paises y peliculas de Disney").lower()
if categoria == 'animales':
    palabra=choice(lista_animales)
elif categoria == 'paises':
    palabra=choice(lista_paises)
elif categoria == 'peliculas de disney':
    palabra=choice(lista_paises)
# Out:
# Elige una categoría entre animales, paises y peliculas de Disneyelectrodomeesticoss
# Categorìa invalida, por favor elige una categoría entre animales, paises y peliculas de Disneyanimales

# %%
display=['_' if letra != ' ' else '   ' for letra in palabra]
print(' '.join(display))

# %%
score=0
while (score < 6) and ('_' in display):
    x=input('Dame una letra')
    if x in palabra:
        for i, letra in enumerate(palabra):
            if x == letra:
                display[i]=x        
    elif x not in palabra:
        score+=1
        error_drawing(score)
    print(' '.join(display))
if score == 6:
    print('Perdiste')
elif '_' not in display:
    print ('Ganaste')
# Out:
# Dame una letraa
# _ a _ _
# Dame una letrat
# _ a t _
# Dame una letraf
# _ a t _
# Dame una letraf
# _ a t _
# Dame una letrat
# _ a t _
# Dame una letrayy
# _ a t _

# %%
def error_drawing(num):
    img = mpimg.imread(str(num)+'.jpg')
    imgplot = plt.imshow(img)
    return(plt.show())
