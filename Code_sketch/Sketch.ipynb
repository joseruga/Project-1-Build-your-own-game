# %%
from random import choice
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import clear_output

# %%
categoria=input("Elige una categoría entre animales, paises y peliculas de Disney").lower()
while categoria not in categorias:
        categoria=input("Categorìa invalida, por favor elige una categoría entre animales, paises y peliculas de Disney").lower()
if categoria == 'animales':
    palabra=choice(lista_animales)
elif categoria == 'paises':
    palabra=choice(lista_paises)
elif categoria == 'peliculas de disney':
    palabra=choice(lista_paises)
# Out:
# Elige una categoría entre animales, paises y peliculas de Disneypaises

# %%
display=['_' if letra != ' ' else '   ' for letra in palabra]
print(' '.join(display))
# Out:
# _ _ _ _ _ _

# %%
score=0
while (score < 6) and ('_' in display):
    x=input('Dame una letra')
    if x in palabra:
        for i, letra in enumerate(palabra):
            if x == letra:
                display[i]=x
        clear_output(wait=True)
    elif x not in palabra:
        score+=1
        clear_output(wait=True)
        error_drawing('sec0'+str(score))
    print(' '.join(display))
if score == 6:
    print('La palabra correcta era '+''.palabra)
    print('Perdiste')
elif '_' not in display:
    print('La palabra correcta es '+''.join(display))
    print ('Ganaste')
# Out:
# e _ _ _ _ _
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-d38c7ddc29d9> in <module>
#       1 score=0
#       2 while (score < 6) and ('_' in display):
# ----> 3     x=input('Dame una letra')
#       4     if x in palabra:
#       5         for i, letra in enumerate(palabra):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
def error_drawing(num):
    img = mpimg.imread(str(num)+'.jpg')
    imgplot = plt.imshow(img)
    return(plt.show())
